# %%
import pandas as pd

# %%
df = pd.read_csv("merge3.csv")
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df_final = df.groupby(['tconst', 'originalTitle', 'primaryTitle', 'averageRating', 'numVotes', 'titleType', 'isAdult', 'startYear', 'runtimeMinutes']).agg({'primaryName':set,'primaryProfession':set,'knownForTitles':set,'category':set,'genres':set}).reset_index()

# %%
df_final['titleType'].unique()
# Out:
# array(['short', 'movie', 'tvShort', 'tvMovie', 'tvEpisode', 'tvSeries',
#        'tvMiniSeries', 'tvSpecial', 'video', 'videoGame'], dtype=object)

# %%
df_final.head()
# Out:
#       tconst           originalTitle            primaryTitle  averageRating  \
# 0  tt0000001              Carmencita              Carmencita            5.7
# 1  tt0000002  Le clown et ses chiens  Le clown et ses chiens            5.5
# 2  tt0000003          Pauvre Pierrot            Poor Pierrot            6.5
# 3  tt0000004             Un bon bock             Un bon bock            5.3
# 4  tt0000005        Blacksmith Scene        Blacksmith Scene            6.2
#
#    numVotes titleType  isAdult startYear runtimeMinutes  \
# 0      2157     short        0      1894              1
# 1       293     short        0      1892              5
# 2      2194     short        0      1892              5
# 3       187     short        0      1892             12
# 4      2942     short        0      1893              1
#
#                                          primaryName  \
# 0  {William K.L. Dickson, William Heise, Carmencita}
# 1                     {Gaston Paulin, Émile Reynaud}
# 2  {Julien Pappé, Gaston Paulin, Tamara Pappé, Ém...
# 3                     {Gaston Paulin, Émile Reynaud}
# 4       {Thomas A. Edison, Charles Kayser, John Ott}
#
#                                    primaryProfession  \
# 0  {soundtrack,archive_footage, cinematographer,d...
# 1  {composer, director,animation_department,produ...
# 2  {cinematographer,animation_department,director...
# 3  {composer, director,animation_department,produ...
# 4           {producer,director,miscellaneous, actor}
#
#                                       knownForTitles  \
# 0  {tt0241715,tt0285863,tt0286096,tt0229665, tt00...
# 1  {tt2184231,tt0000003,tt0000015,tt0000004, tt00...
# 2  {tt7331958,tt0000003,tt20707908,tt0094205, tt0...
# 3  {tt2184231,tt0000003,tt0000015,tt0000004, tt00...
# 4      {\N, tt0361066,tt0242312,tt0004457,tt0001223}
#
#                                          category                      genres
# 0     {cinematographer, self, director, producer}         {Documentary,Short}
# 1                            {composer, director}           {Animation,Short}
# 2  {composer, editor, director, writer, producer}  {Animation,Comedy,Romance}
# 3                            {composer, director}           {Animation,Short}
# 4                               {actor, producer}                     {Short}

# %%
mask = df_final[df_final['titleType'].isin(['short', 'movie', 'tvShort', 'tvMovie'])]

# %%
mask
# Out:
#             tconst           originalTitle            primaryTitle  \
# 0        tt0000001              Carmencita              Carmencita
# 1        tt0000002  Le clown et ses chiens  Le clown et ses chiens
# 2        tt0000003          Pauvre Pierrot            Poor Pierrot
# 3        tt0000004             Un bon bock             Un bon bock
# 4        tt0000005        Blacksmith Scene        Blacksmith Scene
# ...            ...                     ...                     ...
# 1541345  tt9916460               Pink Taxi               Pink Taxi
# 1541349  tt9916538     Kuambil Lagi Hatiku     Kuambil Lagi Hatiku
# 1541350  tt9916544         My Sweet Prince         My Sweet Prince
# 1541362  tt9916706         Dankyavar Danka         Dankyavar Danka
# 1541364  tt9916730                  6 Gunn                  6 Gunn
#
#          averageRating  numVotes titleType  isAdult startYear runtimeMinutes  \
# 0                  5.7      2157     short        0      1894              1
# 1                  5.5       293     short        0      1892              5
# 2                  6.5      2194     short        0      1892              5
# 3                  5.3       187     short        0      1892             12
# 4                  6.2      2942     short        0      1893              1
# ...                ...       ...       ...      ...       ...            ...
# 1541345            8.9        19   tvMovie        0      2019             \N
# 1541349            8.3        10     movie        0      2019            123
# 1541350            6.7        82     short        0      2019             12
# 1541362            7.7         9     movie        0      2013             \N
# 1541364            7.0        13     movie        0      2017            116
#
#                                                primaryName  \
# 0        {William K.L. Dickson, William Heise, Carmencita}
# 1                           {Gaston Paulin, Émile Reynaud}
# 2        {Julien Pappé, Gaston Paulin, Tamara Pappé, Ém...
# 3                           {Gaston Paulin, Émile Reynaud}
# 4             {Thomas A. Edison, Charles Kayser, John Ott}
# ...                                                    ...
# 1541345  {Christina Tafralidou, Giorgos Vezirgiannidis,...
# 1541349  {Azhar Kinoi Lubis, Cut Mini Theo, Dave Lument...
# 1541350  {Yoni Roodner, Sophie Oliver, Jason Synnott, R...
# 1541362  {Makarand Anaspure, Ashwini Ekbote, Sudhir Nik...
# 1541364  {Ganesh Vasant Patil, Sunil Barve, Kiran Gawad...
#
#                                          primaryProfession  \
# 0        {soundtrack,archive_footage, cinematographer,d...
# 1        {composer, director,animation_department,produ...
# 2        {cinematographer,animation_department,director...
# 3        {composer, director,animation_department,produ...
# 4                 {producer,director,miscellaneous, actor}
# ...                                                    ...
# 1541345  {director,editorial_department,editor, cinemat...
# 1541349  {writer,director,producer, editor, actress,arc...
# 1541350  {production_designer,art_director,producer, ac...
# 1541362  {actor,director,producer, actor,producer, writ...
# 1541364  {actor, actress, actor,music_department, direc...
#
#                                             knownForTitles  \
# 0        {tt0241715,tt0285863,tt0286096,tt0229665, tt00...
# 1        {tt2184231,tt0000003,tt0000015,tt0000004, tt00...
# 2        {tt7331958,tt0000003,tt20707908,tt0094205, tt0...
# 3        {tt2184231,tt0000003,tt0000015,tt0000004, tt00...
# 4            {\N, tt0361066,tt0242312,tt0004457,tt0001223}
# ...                                                    ...
# 1541345  {tt14742558,tt9916460, tt9916460, tt14556338,t...
# 1541349  {tt5774688,tt1930290,tt5185980,tt8517144, tt19...
# 1541350  {tt1332123,tt27192052,tt1473818,tt32383976, tt...
# 1541362  {tt9916706, tt6536806,tt17274522,tt0984036,tt9...
# 1541364  {tt2395469,tt13510660,tt27989067,tt20753964, t...
#
#                                                   category  \
# 0              {cinematographer, self, director, producer}
# 1                                     {composer, director}
# 2           {composer, editor, director, writer, producer}
# 3                                     {composer, director}
# 4                                        {actor, producer}
# ...                                                    ...
# 1541345  {editor, director, cinematographer, writer, ac...
# 1541349  {composer, editor, director, cinematographer, ...
# 1541350  {composer, editor, director, cinematographer, ...
# 1541362  {director, cinematographer, writer, actor, act...
# 1541364  {editor, director, cinematographer, writer, ac...
#
#                              genres
# 0               {Documentary,Short}
# 1                 {Animation,Short}
# 2        {Animation,Comedy,Romance}
# 3                 {Animation,Short}
# 4                           {Short}
# ...                             ...
# 1541345                    {Comedy}
# 1541349                     {Drama}
# 1541350               {Drama,Short}
# 1541362                    {Comedy}
# 1541364                     {Drama}
#
# [555220 rows x 14 columns]

# %%
mask = mask[mask['startYear']!="\\N"]

# %%
mask
# Out:
#             tconst           originalTitle            primaryTitle  \
# 0        tt0000001              Carmencita              Carmencita
# 1        tt0000002  Le clown et ses chiens  Le clown et ses chiens
# 2        tt0000003          Pauvre Pierrot            Poor Pierrot
# 3        tt0000004             Un bon bock             Un bon bock
# 4        tt0000005        Blacksmith Scene        Blacksmith Scene
# ...            ...                     ...                     ...
# 1541345  tt9916460               Pink Taxi               Pink Taxi
# 1541349  tt9916538     Kuambil Lagi Hatiku     Kuambil Lagi Hatiku
# 1541350  tt9916544         My Sweet Prince         My Sweet Prince
# 1541362  tt9916706         Dankyavar Danka         Dankyavar Danka
# 1541364  tt9916730                  6 Gunn                  6 Gunn
#
#          averageRating  numVotes titleType  isAdult startYear runtimeMinutes  \
# 0                  5.7      2157     short        0      1894              1
# 1                  5.5       293     short        0      1892              5
# 2                  6.5      2194     short        0      1892              5
# 3                  5.3       187     short        0      1892             12
# 4                  6.2      2942     short        0      1893              1
# ...                ...       ...       ...      ...       ...            ...
# 1541345            8.9        19   tvMovie        0      2019             \N
# 1541349            8.3        10     movie        0      2019            123
# 1541350            6.7        82     short        0      2019             12
# 1541362            7.7         9     movie        0      2013             \N
# 1541364            7.0        13     movie        0      2017            116
#
#                                                primaryName  \
# 0        {William K.L. Dickson, William Heise, Carmencita}
# 1                           {Gaston Paulin, Émile Reynaud}
# 2        {Julien Pappé, Gaston Paulin, Tamara Pappé, Ém...
# 3                           {Gaston Paulin, Émile Reynaud}
# 4             {Thomas A. Edison, Charles Kayser, John Ott}
# ...                                                    ...
# 1541345  {Christina Tafralidou, Giorgos Vezirgiannidis,...
# 1541349  {Azhar Kinoi Lubis, Cut Mini Theo, Dave Lument...
# 1541350  {Yoni Roodner, Sophie Oliver, Jason Synnott, R...
# 1541362  {Makarand Anaspure, Ashwini Ekbote, Sudhir Nik...
# 1541364  {Ganesh Vasant Patil, Sunil Barve, Kiran Gawad...
#
#                                          primaryProfession  \
# 0        {soundtrack,archive_footage, cinematographer,d...
# 1        {composer, director,animation_department,produ...
# 2        {cinematographer,animation_department,director...
# 3        {composer, director,animation_department,produ...
# 4                 {producer,director,miscellaneous, actor}
# ...                                                    ...
# 1541345  {director,editorial_department,editor, cinemat...
# 1541349  {writer,director,producer, editor, actress,arc...
# 1541350  {production_designer,art_director,producer, ac...
# 1541362  {actor,director,producer, actor,producer, writ...
# 1541364  {actor, actress, actor,music_department, direc...
#
#                                             knownForTitles  \
# 0        {tt0241715,tt0285863,tt0286096,tt0229665, tt00...
# 1        {tt2184231,tt0000003,tt0000015,tt0000004, tt00...
# 2        {tt7331958,tt0000003,tt20707908,tt0094205, tt0...
# 3        {tt2184231,tt0000003,tt0000015,tt0000004, tt00...
# 4            {\N, tt0361066,tt0242312,tt0004457,tt0001223}
# ...                                                    ...
# 1541345  {tt14742558,tt9916460, tt9916460, tt14556338,t...
# 1541349  {tt5774688,tt1930290,tt5185980,tt8517144, tt19...
# 1541350  {tt1332123,tt27192052,tt1473818,tt32383976, tt...
# 1541362  {tt9916706, tt6536806,tt17274522,tt0984036,tt9...
# 1541364  {tt2395469,tt13510660,tt27989067,tt20753964, t...
#
#                                                   category  \
# 0              {cinematographer, self, director, producer}
# 1                                     {composer, director}
# 2           {composer, editor, director, writer, producer}
# 3                                     {composer, director}
# 4                                        {actor, producer}
# ...                                                    ...
# 1541345  {editor, director, cinematographer, writer, ac...
# 1541349  {composer, editor, director, cinematographer, ...
# 1541350  {composer, editor, director, cinematographer, ...
# 1541362  {director, cinematographer, writer, actor, act...
# 1541364  {editor, director, cinematographer, writer, ac...
#
#                              genres
# 0               {Documentary,Short}
# 1                 {Animation,Short}
# 2        {Animation,Comedy,Romance}
# 3                 {Animation,Short}
# 4                           {Short}
# ...                             ...
# 1541345                    {Comedy}
# 1541349                     {Drama}
# 1541350               {Drama,Short}
# 1541362                    {Comedy}
# 1541364                     {Drama}
#
# [555220 rows x 14 columns]

# %%
mask = mask[mask["startYear"].notna()]
mask["startYear"] = mask["startYear"].astype(int)

# %%
mask_date = mask[mask['startYear'] >= 1945]

# %%
mask_date
# Out:
#             tconst         originalTitle          primaryTitle  averageRating  \
# 598      tt0000929  Klebolin klebt alles  Klebolin klebt alles            5.2
# 4888     tt0015724         Dama de noche         Dama de noche            6.3
# 7973     tt0021617     Arizona Territory     Arizona Territory            5.9
# 8311     tt0022064         Lebbra bianca         Lebbra bianca            5.2
# 9193     tt0023239   Mother-In-Law's Day   Mother-in-Law's Day            5.6
# ...            ...                   ...                   ...            ...
# 1541345  tt9916460             Pink Taxi             Pink Taxi            8.9
# 1541349  tt9916538   Kuambil Lagi Hatiku   Kuambil Lagi Hatiku            8.3
# 1541350  tt9916544       My Sweet Prince       My Sweet Prince            6.7
# 1541362  tt9916706       Dankyavar Danka       Dankyavar Danka            7.7
# 1541364  tt9916730                6 Gunn                6 Gunn            7.0
#
#          numVotes titleType  isAdult  startYear runtimeMinutes  \
# 598            49     short        0       1990             \N
# 4888           32     movie        0       1993            102
# 7973           62     movie        0       1950             56
# 8311           62     movie        0       1951             80
# 9193            8     short        0       1945             18
# ...           ...       ...      ...        ...            ...
# 1541345        19   tvMovie        0       2019             \N
# 1541349        10     movie        0       2019            123
# 1541350        82     short        0       2019             12
# 1541362         9     movie        0       2013             \N
# 1541364        13     movie        0       2017            116
#
#                                                primaryName  \
# 598      {Victor Colani, Alfred Duskes, Ernst Behmer, C...
# 4888     {Rafael Sánchez Navarro, Cecilia Toussaint, Re...
# 7973     {Richard V. Heermance, Nancy Saunders, Bud Osb...
# 8311     {Amedeo Nazzari, Giulio Donnini, Umberto Spada...
# 9193     {Edward W. Williams, Jack Rice, Dot Farley, Ed...
# ...                                                    ...
# 1541345  {Christina Tafralidou, Giorgos Vezirgiannidis,...
# 1541349  {Azhar Kinoi Lubis, Cut Mini Theo, Dave Lument...
# 1541350  {Yoni Roodner, Sophie Oliver, Jason Synnott, R...
# 1541362  {Makarand Anaspure, Ashwini Ekbote, Sudhir Nik...
# 1541364  {Ganesh Vasant Patil, Sunil Barve, Kiran Gawad...
#
#                                          primaryProfession  \
# 598      {actor, actor,director,writer, producer,direct...
# 4888     {cinematographer,actor,director, actor,produce...
# 7973     {actor,stunts, director,assistant_director,pro...
# 8311     {cinematographer,writer,director, composer, ac...
# 9193     {director,writer,miscellaneous, producer,write...
# ...                                                    ...
# 1541345  {director,editorial_department,editor, cinemat...
# 1541349  {writer,director,producer, editor, actress,arc...
# 1541350  {production_designer,art_director,producer, ac...
# 1541362  {actor,director,producer, actor,producer, writ...
# 1541364  {actor, actress, actor,music_department, direc...
#
#                                             knownForTitles  \
# 598      {tt11272014,tt7417070,tt0830870,tt0013829, tt0...
# 4888     {tt0015724,tt0097912,tt0071328,tt0088712, tt04...
# 7973     {tt0017570,tt0169306,tt0010781,tt0047802, tt00...
# 8311     {tt0056945,tt0046268,tt0056558,tt0040773, tt00...
# 9193     {tt0023969,tt0029606,tt0028171,tt0023327, tt00...
# ...                                                    ...
# 1541345  {tt14742558,tt9916460, tt9916460, tt14556338,t...
# 1541349  {tt5774688,tt1930290,tt5185980,tt8517144, tt19...
# 1541350  {tt1332123,tt27192052,tt1473818,tt32383976, tt...
# 1541362  {tt9916706, tt6536806,tt17274522,tt0984036,tt9...
# 1541364  {tt2395469,tt13510660,tt27989067,tt20753964, t...
#
#                                                   category  \
# 598           {cinematographer, actor, producer, director}
# 4888     {composer, editor, director, cinematographer, ...
# 7973     {editor, director, cinematographer, writer, ac...
# 8311     {composer, editor, director, cinematographer, ...
# 9193     {editor, director, writer, actor, actress, pro...
# ...                                                    ...
# 1541345  {editor, director, cinematographer, writer, ac...
# 1541349  {composer, editor, director, cinematographer, ...
# 1541350  {composer, editor, director, cinematographer, ...
# 1541362  {director, cinematographer, writer, actor, act...
# 1541364  {editor, director, cinematographer, writer, ac...
#
#                           genres
# 598               {Comedy,Short}
# 4888     {Drama,Mystery,Romance}
# 7973             {Drama,Western}
# 8311                     {Drama}
# 9193              {Comedy,Short}
# ...                          ...
# 1541345                 {Comedy}
# 1541349                  {Drama}
# 1541350            {Drama,Short}
# 1541362                 {Comedy}
# 1541364                  {Drama}
#
# [517307 rows x 14 columns]

# %%
mask_vote = mask_date[mask_date["numVotes"] >= 5000]

# %%
mask_vote
# Out:
#             tconst                originalTitle                 primaryTitle  \
# 13260    tt0028445           Partie de campagne         A Day in the Country
# 19051    tt0035423               Kate & Leopold               Kate & Leopold
# 20268    tt0036868  The Best Years of Our Lives  The Best Years of Our Lives
# 20794    tt0037514               Anchors Aweigh               Anchors Aweigh
# 20795    tt0037515     And Then There Were None     And Then There Were None
# ...            ...                          ...                          ...
# 1540638  tt9898858              Coffee & Kareem              Coffee & Kareem
# 1540747  tt9900782                       Kaithi                       Kaithi
# 1540774  tt9902160                      Herself                      Herself
# 1540947  tt9907782             Eight for Silver                   The Cursed
# 1541338  tt9916362                     Akelarre                        Coven
#
#          averageRating  numVotes titleType  isAdult  startYear runtimeMinutes  \
# 13260              7.5      7427     short        0       1946             40
# 19051              6.4     91790     movie        0       2001            118
# 20268              8.1     74474     movie        0       1946            170
# 20794              7.0      9755     movie        0       1945            140
# 20795              7.4     17602     movie        0       1945             97
# ...                ...       ...       ...      ...        ...            ...
# 1540638            5.2     14914     movie        0       2020             88
# 1540747            8.4     46603     movie        0       2019            145
# 1540774            7.0      5099     movie        0       2020             97
# 1540947            6.2     20305     movie        0       2021            111
# 1541338            6.4      6042     movie        0       2020             92
#
#                                                primaryName  \
# 13260    {Jacques B. Brunius, Gabrielle Fontan, Guy de ...
# 19051    {Meg Ryan, Mark Friedberg, Kerry Barden, Stuar...
# 20268    {Fredric March, Myrna Loy, Teresa Wright, Glad...
# 20794    {Billy Gilbert, Carlos Ramírez, Gene Kelly, He...
# 20795    {Mario Castelnuovo-Tedesco, Barry Fitzgerald, ...
# ...                                                    ...
# 1540638  {Shane Mack, Daniel Gabbe, Mike Falbo, William...
# 1540747  {Ramana, S.R. Prakashbabu, Sathyan Sooryan, Lo...
# 1540774  {Ed Guiney, Rebecca Lloyd, Ian Lloyd Anderson,...
# 1540947  {Max Mackintosh, Thierry Zemmour, Mickey Lidde...
# 1541338  {Nathalie Camidebach, Daniel Fanego, Florencia...
#
#                                          primaryProfession  \
# 13260    {writer,archive_footage, editor, writer,direct...
# 19051    {writer,producer,miscellaneous, actor, product...
# 20268    {actor,music_department,composer, director,pro...
# 20794    {actor,miscellaneous,director, writer,archive_...
# 20795    {writer,director,producer, actor,director,prod...
# ...                                                    ...
# 1540638  {actor,director,producer, actor,producer, actr...
# 1540747  {writer,director,producer, editor,camera_depar...
# 1540774  {actress,miscellaneous,writer, production_desi...
# 1540947  {production_designer,art_department,art_direct...
# 1541338  {writer,director,producer, producer,miscellane...
#
#                                             knownForTitles  \
# 13260    {tt0031885,tt0028950,tt0054407,tt0025898, tt11...
# 19051    {tt0090685,tt0035423,tt0092605,tt0108778, tt01...
# 20268    {tt0036868,tt0042530,tt0035970,tt0029264, tt00...
# 20794    {tt0037514, tt0032299,tt0028313,tt0024786,tt00...
# 20795    {tt0059742,tt0043274,tt0033373,tt0037515, tt13...
# ...                                                    ...
# 1540638  {tt9898858,tt6217976,tt3009772,tt5461956, tt98...
# 1540747  {tt9900782,tt10579952,tt9179430,tt18926098, tt...
# 1540774  {tt4374208,tt8430356,tt0867005,tt2704998, tt15...
# 1540947  {tt14230458,tt5083738,tt3464902,tt1379182, tt1...
# 1541338  {tt27729779,tt4610958,tt23810872,tt16156592, t...
#
#                                                   category  \
# 13260    {composer, editor, director, cinematographer, ...
# 19051    {casting_director, composer, editor, director,...
# 20268    {composer, editor, director, cinematographer, ...
# 20794    {editor, director, cinematographer, writer, ac...
# 20795    {composer, editor, director, cinematographer, ...
# ...                                                    ...
# 1540638  {casting_director, composer, editor, director,...
# 1540747  {composer, editor, director, cinematographer, ...
# 1540774  {casting_director, composer, editor, director,...
# 1540947  {casting_director, composer, editor, director,...
# 1541338  {casting_director, composer, editor, director,...
#
#                            genres
# 13260      {Comedy,Drama,Romance}
# 19051    {Comedy,Fantasy,Romance}
# 20268         {Drama,Romance,War}
# 20794    {Comedy,Fantasy,Musical}
# 20795       {Crime,Drama,Mystery}
# ...                           ...
# 1540638     {Action,Comedy,Crime}
# 1540747   {Action,Crime,Thriller}
# 1540774                   {Drama}
# 1540947  {Fantasy,Horror,Mystery}
# 1541338           {Drama,History}
#
# [18002 rows x 14 columns]

# %%
tmdb_csv = pd.read_csv("tmdb_csv")

# %%
df_fin = pd.merge(mask_vote, tmdb_csv, left_on="tconst", right_on="imdb_id")

# %%
df_fin = df_fin.drop(columns="tconst")

# %%
df_fin = df_fin.drop(columns="Unnamed: 0")

# %%
df_fin = df_fin.drop(columns="tagline")

# %%
df_fin = df_fin.set_index("imdb_id")

# %%
df_fin.isna().sum()
# Out:
# originalTitle                    0
# primaryTitle                     0
# averageRating                    0
# numVotes                         0
# titleType                        0
# isAdult                          0
# startYear                        0
# runtimeMinutes                   0
# primaryName                      0
# primaryProfession                0
# knownForTitles                   0
# category                         0
# genres                           0
# backdrop_path                  426
# budget                           0
# homepage                     11873
# overview                        65
# poster_path                    165
# production_countries             0
# release_date                   227
# production_companies_name        0
# dtype: int64

# %%
import numpy as np

# %%
df_fin["release_date"].replace("", np.nan, inplace=True)
df_fin["release_date"].replace(" ", np.nan, inplace=True)
df_fin["release_date"] = df_fin["release_date"].fillna(df_fin["startYear"])
# Out:
# C:\Users\valen\AppData\Local\Temp\ipykernel_7696\4275061853.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_fin["release_date"].replace("", np.nan, inplace=True)
# C:\Users\valen\AppData\Local\Temp\ipykernel_7696\4275061853.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_fin["release_date"].replace(" ", np.nan, inplace=True)

# %%
df_fin["startYear"] = df_fin["startYear"].astype(str)  # ou int selon besoin
df_fin["release_date"] = df_fin["release_date"].fillna(df_fin["startYear"])

# %%
df_fin["overview"].replace(["", " "], np.nan, inplace=True)

# Ensuite remplacer les NaN
df_fin["overview"] = df_fin["overview"].fillna("Pas de résumé disponible")
# Out:
# C:\Users\valen\AppData\Local\Temp\ipykernel_7696\1899933587.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_fin["overview"].replace(["", " "], np.nan, inplace=True)

# %%
df_fin
# Out:
#                          originalTitle                 primaryTitle  \
# imdb_id
# tt0028445           Partie de campagne         A Day in the Country
# tt0035423               Kate & Leopold               Kate & Leopold
# tt0036868  The Best Years of Our Lives  The Best Years of Our Lives
# tt0037514               Anchors Aweigh               Anchors Aweigh
# tt0037515     And Then There Were None     And Then There Were None
# ...                                ...                          ...
# tt9898858              Coffee & Kareem              Coffee & Kareem
# tt9900782                       Kaithi                       Kaithi
# tt9902160                      Herself                      Herself
# tt9907782             Eight for Silver                   The Cursed
# tt9916362                     Akelarre                        Coven
#
#            averageRating  numVotes titleType startYear runtimeMinutes  \
# imdb_id
# tt0028445            7.5      7427     short      1946             40
# tt0035423            6.4     91790     movie      2001            118
# tt0036868            8.1     74474     movie      1946            170
# tt0037514            7.0      9755     movie      1945            140
# tt0037515            7.4     17602     movie      1945             97
# ...                  ...       ...       ...       ...            ...
# tt9898858            5.2     14914     movie      2020             88
# tt9900782            8.4     46603     movie      2019            145
# tt9902160            7.0      5099     movie      2020             97
# tt9907782            6.2     20305     movie      2021            111
# tt0036868  ['Samuel Goldwyn Productions', 'RKO Radio Pict...
# tt0037514                            ['Metro-Goldwyn-Mayer']
# tt0037515     ['Rene Clair Productions', '20th Century Fox']
# ...                                                      ...
# tt9898858  ['Pacific Electric Picture Company', 'Palm Dri...
# tt9900782  ['Dream Warrior Pictures', 'Vivekandanda Pictu...
# tt9902160  ['Element Pictures', 'BBC Film', 'Merman', 'Am...
# tt9907782                ['Piste Rouge', 'LD Entertainment']
# tt9916362  ['INCAA', 'La Fidèle Production', 'Lamia Produ...
#
# [17526 rows x 20 columns]

# %%
df_fin = df_fin[df_fin["isAdult"] != 1]

# %%
df_fin = df_fin.drop(columns=["isAdult"])

# %%
df_fin["overview"].iloc[:5]
# Out:
# imdb_id
# tt0028445    The family of a Parisian shop-owner spends a d...
# tt0035423    When her scientist ex-boyfriend discovers a po...
# tt0036868    It's the hope that sustains the spirit of ever...
# tt0037514    Two sailors, Joe and Clarence have four days s...
# tt0037515    Ten strangers are summoned to a remote island ...
# Name: overview, dtype: object

# %%
! pip install googletrans
import time
from googletrans import Translator
# Out:
# Collecting googletrans
#   Downloading googletrans-4.0.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: httpx>=0.27.2 in c:\users\alex\appdata\local\programs\python\python313\lib\site-packages (from httpx[http2]>=0.27.2->googletrans) (0.28.1)
# Requirement already satisfied: anyio in c:\users\alex\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.27.2->httpx[http2]>=0.27.2->googletrans) (4.9.0)
# Requirement already satisfied: certifi in c:\users\alex\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.27.2->httpx[http2]>=0.27.2->googletrans) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\alex\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.27.2->httpx[http2]>=0.27.2->googletrans) (1.0.9)
# Requirement already satisfied: idna in c:\users\alex\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.27.2->httpx[http2]>=0.27.2->googletrans) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\alex\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx>=0.27.2->httpx[http2]>=0.27.2->googletrans) (0.16.0)
# Collecting h2<5,>=3 (from httpx[http2]>=0.27.2->googletrans)
#   Downloading h2-4.2.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting hyperframe<7,>=6.1 (from h2<5,>=3->httpx[http2]>=0.27.2->googletrans)
#   Downloading hyperframe-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting hpack<5,>=4.1 (from h2<5,>=3->httpx[http2]>=0.27.2->googletrans)
#   Downloading hpack-4.1.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: sniffio>=1.1 in c:\users\alex\appdata\local\programs\python\python313\lib\site-packages (from anyio->httpx>=0.27.2->httpx[http2]>=0.27.2->googletrans) (1.3.1)
# Downloading googletrans-4.0.2-py3-none-any.whl (18 kB)
# Downloading h2-4.2.0-py3-none-any.whl (60 kB)
# Downloading hpack-4.1.0-py3-none-any.whl (34 kB)
# Downloading hyperframe-6.1.0-py3-none-any.whl (13 kB)
# Installing collected packages: hyperframe, hpack, h2, googletrans
# Successfully installed googletrans-4.0.2 h2-4.2.0 hpack-4.1.0 hyperframe-6.1.0
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
translator = Translator()

def translate_with_pause(text):
    time.sleep(15)  # pause d'une seconde
    return translator.translate(text, src="en", dest="fr").text

df_fin["overview_fr"] = df_fin["overview"].apply(translate_with_pause)
# Out:
# ---------------------------------------------------------------------------
# ConnectTimeout                            Traceback (most recent call last)
# Cell In[209], line 7
#       4     time.sleep(3)  # pause d'une seconde
#       5     return translator.translate(text, src="en", dest="fr").text
# ----> 7 df_fin["overview_fr"] = df_fin["overview"].apply(translate_with_pause)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)   4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)   4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[209], line 5, in translate_with_pause(text)
#       3 def translate_with_pause(text):
#       4     time.sleep(3)  # pause d'une seconde
# ----> 5     return translator.translate(text, src="en", dest="fr").text
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\googletrans\client.py:210, in Translator.translate(self, text, dest, src, **kwargs)
#     207     return result
#     209 origin = text
# --> 210 data, response = self._translate(text, dest, src, kwargs)
#     212 # this code will be updated when the format is changed.
#     213 translated = ''.join([d[0] if d[0] else '' for d in data[0]])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\googletrans\client.py:108, in Translator._translate(self, text, dest, src, override)
#     104 params = utils.build_params(client=self.client_type, query=text, src=src, dest=dest,
#     105                             token=token, override=override)
#     107 url = urls.TRANSLATE.format(host=self._pick_service_url())
# --> 108 r = self.client.get(url, params=params)
#     110 if r.status_code == 200:
#     111     data = utils.format_json(r.text)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\httpx\_client.py:755, in Client.get(self, url, params, headers, cookies, auth, allow_redirects, timeout)
#     744 def get(
#     745     self,
#     746     url: URLTypes,
#    (...)    753     timeout: typing.Union[TimeoutTypes, UnsetType] = UNSET,
#     754 ) -> Response:
# --> 755     return self.request(
#     756         "GET",
#     757         url,
#     758         params=params,
#     759         headers=headers,
#     760         cookies=cookies,
#     761         auth=auth,
#     762         allow_redirects=allow_redirects,
#     763         timeout=timeout,
#     764     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\httpx\_client.py:600, in Client.request(self, method, url, data, files, json, params, headers, cookies, auth, allow_redirects, timeout)
#     575 def request(
#     576     self,
#     577     method: str,
#    (...)    588     timeout: typing.Union[TimeoutTypes, UnsetType] = UNSET,
#     589 ) -> Response:
#     590     request = self.build_request(
#     591         method=method,
#     592         url=url,
#    (...)    598         cookies=cookies,
#     599     )
# --> 600     return self.send(
#     601         request, auth=auth, allow_redirects=allow_redirects, timeout=timeout,
#     602     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\httpx\_client.py:620, in Client.send(self, request, stream, auth, allow_redirects, timeout)
#     616 timeout = self.timeout if isinstance(timeout, UnsetType) else Timeout(timeout)
#     618 auth = self.build_auth(request, auth)
# --> 620 response = self.send_handling_redirects(
#     621     request, auth=auth, timeout=timeout, allow_redirects=allow_redirects,
#     622 )
#     624 if not stream:
#     625     try:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\httpx\_client.py:647, in Client.send_handling_redirects(self, request, auth, timeout, allow_redirects, history)
#     644 if len(history) > self.max_redirects:
#     645     raise TooManyRedirects()
# --> 647 response = self.send_handling_auth(
#     648     request, auth=auth, timeout=timeout, history=history
#     649 )
#     650 response.history = list(history)
#     652 if not response.is_redirect:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\httpx\_client.py:684, in Client.send_handling_auth(self, request, history, auth, timeout)
#     682 request = next(auth_flow)
#     683 while True:
# --> 684     response = self.send_single_request(request, timeout)
#     685     if auth.requires_response_body:
#     686         response.read()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\httpx\_client.py:714, in Client.send_single_request(self, request, timeout)
#     705 transport = self.transport_for_url(request.url)
#     707 try:
#     708     (
#     709         http_version,
#     710         status_code,
#     711         reason_phrase,
#     712         headers,
#     713         stream,
# --> 714     ) = transport.request(
#     715         request.method.encode(),
#     716         request.url.raw,
#     717         headers=request.headers.raw,
#     718         stream=request.stream,
#     719         timeout=timeout.as_dict(),
#     720     )
#     721 except HTTPError as exc:
#     722     # Add the original request to any HTTPError unless
#     723     # there'a already a request attached in the case of
#     724     # a ProxyError.
#     725     if exc._request is None:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\httpcore\_sync\connection_pool.py:152, in SyncConnectionPool.request(self, method, url, headers, stream, timeout)
#     149         logger.trace("reuse connection=%r", connection)
#     151 try:
# --> 152     response = connection.request(
#     153         method, url, headers=headers, stream=stream, timeout=timeout
#     154     )
#     155 except NewConnectionRequired:
#     156     connection = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\httpcore\_sync\connection.py:65, in SyncHTTPConnection.request(self, method, url, headers, stream, timeout)
#      61     if not self.socket:
#      62         logger.trace(
#      63             "open_socket origin=%r timeout=%r", self.origin, timeout
#      64         )
# ---> 65         self.socket = self._open_socket(timeout)
#      66     self._create_connection(self.socket)
#      67 elif self.state in (ConnectionState.READY, ConnectionState.IDLE):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\httpcore\_sync\connection.py:85, in SyncHTTPConnection._open_socket(self, timeout)
#      83 ssl_context = self.ssl_context if scheme == b"https" else None
#      84 try:
# ---> 85     return self.backend.open_tcp_stream(
#      86         hostname, port, ssl_context, timeout
#      87     )
#      88 except Exception:
#      89     self.connect_failed = True
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\httpcore\_backends\sync.py:133, in SyncBackend.open_tcp_stream(self, hostname, port, ssl_context, timeout)
#     130 connect_timeout = timeout.get("connect")
#     131 exc_map = {socket.timeout: ConnectTimeout, socket.error: ConnectError}
# --> 133 with map_exceptions(exc_map):
#     134     sock = socket.create_connection(address, connect_timeout)
#     135     if ssl_context is not None:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     156     value = typ()
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#     163     return exc is not value
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\httpcore\_exceptions.py:12, in map_exceptions(map)
#      10 for from_exc, to_exc in map.items():
#      11     if isinstance(exc, from_exc):
# ---> 12         raise to_exc(exc) from None
#      13 raise
#
# ConnectTimeout: _ssl.c:993: The handshake operation timed out

# %%
# !pip3 install googletrans==3.1.0a0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting googletrans==3.1.0a0
#   Downloading googletrans-3.1.0a0.tar.gz (19 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting httpx==0.13.3 (from googletrans==3.1.0a0)
#   Downloading httpx-0.13.3-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: certifi in c:\users\valen\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2025.1.31)
# Collecting hstspreload (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading hstspreload-2025.1.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: sniffio in c:\users\valen\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.3.1)
# Collecting chardet==3.* (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading chardet-3.0.4-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting idna==2.* (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading idna-2.10-py2.py3-none-any.whl.metadata (9.1 kB)
# Collecting rfc3986<2,>=1.3 (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting httpcore==0.9.* (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading httpcore-0.9.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting h11<0.10,>=0.8 (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading h11-0.9.0-py2.py3-none-any.whl.metadata (8.1 kB)
# Collecting h2==3.* (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading h2-3.2.0-py2.py3-none-any.whl.metadata (32 kB)
# Collecting hyperframe<6,>=5.2.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl.metadata (7.2 kB)
# Collecting hpack<4,>=3.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading hpack-3.0.0-py2.py3-none-any.whl.metadata (7.0 kB)
# Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
# Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
# Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
# Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Downloading hstspreload-2025.1.1-py3-none-any.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 1.3/1.3 MB 11.1 MB/s eta 0:00:00
# Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
# Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (pyproject.toml): started
#   Building wheel for googletrans (pyproject.toml): finished with status 'done'
#   Created wheel for googletrans: filename=googletrans-3.1.0a0-py3-none-any.whl size=16474 sha256=1c1020d5de203c639ef6337b989eecdc1d8ae97c966714bca799fb80942404e3
#   Stored in directory: c:\users\valen\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local\pip\cache\wheels\96\ac\bd\9df9eab356c0576896e97147425987f6f45e9e46456c978d18
# Successfully built googletrans
# Installing collected packages: rfc3986, hyperframe, hpack, h11, chardet, idna, hstspreload, h2, httpcore, httpx, googletrans
#   Attempting uninstall: h11
#     Found existing installation: h11 0.16.0
#     Uninstalling h11-0.16.0:
#       Successfully uninstalled h11-0.16.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
#   Attempting uninstall: httpcore
#     Found existing installation: httpcore 1.0.9
#     Uninstalling httpcore-1.0.9:
#       Successfully uninstalled httpcore-1.0.9
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.28.1
#     Uninstalling httpx-0.28.1:
#       Successfully uninstalled httpx-0.28.1
# Successfully installed chardet-3.0.4 googletrans-3.1.0a0 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2025.1.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 idna-2.10 rfc3986-1.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-genai 1.13.0 requires httpx<1.0.0,>=0.28.1, but you have httpx 0.13.3 which is incompatible.
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: C:\Users\valen\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from googletrans import Translator

translator = Translator()
translator.translate("The inspiring true story of Dream Alliance, an unlikely race horse bred by small town bartender, Jan Vokes. With very little money and no experience, Jan convinces her neighbors to chip in their meager earnings to help raise Dream and compete with the racing elites. Their investment pays off as Dream rises through the ranks and becomes a beacon of hope in their struggling community.", src="en", dest="fr").text
# Out:
# "L'histoire vraie inspirante de Dream Alliance, un cheval de course improbable élevé par le barman de petite ville, Jan Vokes. Avec très peu d'argent et aucune expérience, Jan convainc ses voisins de cogner leurs maigres gains pour aider à élever le rêve et à rivaliser avec les élites de course. Leur investissement est payant alors que Dream monte dans les rangs et devient un phare d'espoir dans leur communauté en difficulté."

# %%
df_fin=pd.read_csv("df_fin.csv")

# %%
df_fin=df_fin.set_index("imdb_id")
df_fin
# Out:
#                          originalTitle                 primaryTitle  \
# imdb_id
# tt0028445           Partie de campagne         A Day in the Country
# tt0035423               Kate & Leopold               Kate & Leopold
# tt0036868  The Best Years of Our Lives  The Best Years of Our Lives
# tt0037514               Anchors Aweigh               Anchors Aweigh
# tt0037515     And Then There Were None     And Then There Were None
# ...                                ...                          ...
# tt9898858              Coffee & Kareem              Coffee & Kareem
# tt9900782                       Kaithi                       Kaithi
# tt9902160                      Herself                      Herself
# tt9907782             Eight for Silver                   The Cursed
# tt9916362                     Akelarre                        Coven
#
#            averageRating  numVotes titleType  startYear runtimeMinutes  \
# imdb_id
# tt0028445            7.5      7427     short       1946             40
# tt0035423            6.4     91790     movie       2001            118
# tt0036868            8.1     74474     movie       1946            170
# tt0037514            7.0      9755     movie       1945            140
# tt0037515            7.4     17602     movie       1945             97
# ...                  ...       ...       ...        ...            ...
# tt9898858            5.2     14914     movie       2020             88
# tt9907782  /bewmBcjJxHeipS1PNu9Lfyvt3zY.jpg               ['US']   2021-07-28
# tt9916362  /lyB3yoQbGO3LiCVuSOD2g17Hr6p.jpg   ['AR', 'ES', 'FR']   2020-10-02
#
#                                    production_companies_name
# imdb_id
# tt0028445                           ['Panthéon Productions']
# tt0035423                     ['Konrad Pictures', 'Miramax']
# tt0036868  ['Samuel Goldwyn Productions', 'RKO Radio Pict...
# tt0037514                            ['Metro-Goldwyn-Mayer']
# tt0037515     ['Rene Clair Productions', '20th Century Fox']
# ...                                                      ...
# tt9898858  ['Pacific Electric Picture Company', 'Palm Dri...
# tt9900782  ['Dream Warrior Pictures', 'Vivekandanda Pictu...
# tt9902160  ['Element Pictures', 'BBC Film', 'Merman', 'Am...
# tt9907782                ['Piste Rouge', 'LD Entertainment']
# tt9916362  ['INCAA', 'La Fidèle Production', 'Lamia Produ...
#
# [17526 rows x 20 columns]

# %%
listevide = [

]
for txt in df_fin["overview"][10001:1000]:
    try:
        res = await translator.translate(txt, src="en", dest="fr")
        listevide.append(res.text)
    except:
        print("deco")

# %%
base = "https://image.tmdb.org/t/p/w500/"
df_fin["url_complet"]=df_fin["poster_path"].apply(lambda url: base + str(url) )

# %%
df_fin.iloc[500]["url_complet"]
# Out:
# 'https://image.tmdb.org/t/p/w500//hJJtV5puzYAODgck0JTWVX8zjKu.jpg'

# %%
df_fin =  df_fin.drop(columns=["backdrop_path"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df_fin =  df_fin.drop(columns=["backdrop_path"])
#       2 df_fin =  df_fin.drop(columns=["poster_path"])
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)   5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)   5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['backdrop_path'] not found in axis"

# %%
df_fin =  df_fin.drop(columns=["poster_path"])

# %%
df_fin
# Out:
#                          originalTitle                 primaryTitle  \
# imdb_id
# tt0028445           Partie de campagne         A Day in the Country
# tt0035423               Kate & Leopold               Kate & Leopold
# tt0036868  The Best Years of Our Lives  The Best Years of Our Lives
# tt0037514               Anchors Aweigh               Anchors Aweigh
# tt0037515     And Then There Were None     And Then There Were None
# ...                                ...                          ...
# tt9898858              Coffee & Kareem              Coffee & Kareem
# tt9900782                       Kaithi                       Kaithi
# tt9902160                      Herself                      Herself
# tt9907782             Eight for Silver                   The Cursed
# tt9916362                     Akelarre                        Coven
#
#            averageRating  numVotes titleType  startYear runtimeMinutes  \
# imdb_id
# tt0028445            7.5      7427     short       1946             40
# tt0035423            6.4     91790     movie       2001            118
# tt0036868            8.1     74474     movie       1946            170
# tt0037514            7.0      9755     movie       1945            140
# tt0037515            7.4     17602     movie       1945             97
# ...                  ...       ...       ...        ...            ...
# tt9898858            5.2     14914     movie       2020             88
# tt9900782            8.4     46603     movie       2019            145
# tt9902160            7.0      5099     movie       2020             97
# tt9907782            6.2     20305     movie       2021            111
# tt9916362            6.4      6042     movie       2020             92
#
#                                                  primaryName  \
# imdb_id
# tt0028445  {'Jean Renoir', 'Pierre Lestringuez', 'Guy de ...
# tt0035423  {'Bradley Whitford', 'Liev Schreiber', 'Brecki...
# tt0036868  {'Myrna Loy', 'Virginia Mayo', 'Roman Bohnen',...
